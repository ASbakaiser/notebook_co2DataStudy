# %% [markdown]
# # Study of Co2 from 1700 to 2020 by country

# %%
#######################################################################

# %% [markdown]
# # Imports librairies

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # import data from csv

# %%
data = pd.read_csv("co2_emission_by_countries.csv", encoding="latin")

# %% [markdown]
# # reading data as dataframe

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#            Country Code Calling Code  Year  CO2 emission (Tons)
# 0      Afghanistan   AF           93  1750                  0.0  \
# 1      Afghanistan   AF           93  1751                  0.0
# 2      Afghanistan   AF           93  1752                  0.0
# 3      Afghanistan   AF           93  1753                  0.0
# 4      Afghanistan   AF           93  1754                  0.0
# ...            ...  ...          ...   ...                  ...
# 59615     Zimbabwe   ZW          263  2016          736467042.0
# 59616     Zimbabwe   ZW          263  2017          746048675.0
# 59617     Zimbabwe   ZW          263  2018          757903042.0
# 59618     Zimbabwe   ZW          263  2019          768852126.0
# 59619     Zimbabwe   ZW          263  2020          779383468.0
#
#        Population(2022)      Area % of World Density(km2)
# 0            41128771.0  652230.0      0.40%       63/km²
# 1            41128771.0  652230.0      0.40%       63/km²
# 2            41128771.0  652230.0      0.40%       63/km²
# 3            41128771.0  652230.0      0.40%       63/km²
# 4            41128771.0  652230.0      0.40%       63/km²
# ...                 ...       ...        ...          ...
# 59615        16320537.0  390757.0      0.30%       42/km²
# 59616        16320537.0  390757.0      0.30%       42/km²
# 59617        16320537.0  390757.0      0.30%       42/km²
# 59618        16320537.0  390757.0      0.30%       42/km²
# 59619        16320537.0  390757.0      0.30%       42/km²
#
# [59620 rows x 9 columns]

# %% [markdown]
# # Remove usless columns as "Calling code" and "Code"

# %%
df1 = df.drop(columns=['Calling Code','Code'])

# %%
df1
# Out:
#            Country  Year  CO2 emission (Tons)  Population(2022)      Area
# 0      Afghanistan  1750                  0.0        41128771.0  652230.0  \
# 1      Afghanistan  1751                  0.0        41128771.0  652230.0
# 2      Afghanistan  1752                  0.0        41128771.0  652230.0
# 3      Afghanistan  1753                  0.0        41128771.0  652230.0
# 4      Afghanistan  1754                  0.0        41128771.0  652230.0
# ...            ...   ...                  ...               ...       ...
# 59615     Zimbabwe  2016          736467042.0        16320537.0  390757.0
# 59616     Zimbabwe  2017          746048675.0        16320537.0  390757.0
# 59617     Zimbabwe  2018          757903042.0        16320537.0  390757.0
# 59618     Zimbabwe  2019          768852126.0        16320537.0  390757.0
# 59619     Zimbabwe  2020          779383468.0        16320537.0  390757.0
#
#       % of World Density(km2)
# 0          0.40%       63/km²
# 1          0.40%       63/km²
# 2          0.40%       63/km²
# 3          0.40%       63/km²
# 4          0.40%       63/km²
# ...          ...          ...
# 59615      0.30%       42/km²
# 59616      0.30%       42/km²
# 59617      0.30%       42/km²
# 59618      0.30%       42/km²
# 59619      0.30%       42/km²
#
# [59620 rows x 7 columns]

# %% [markdown]
# # Rename columns of select easier

# %%
df1 = df1.rename(columns={'CO2 emission (Tons)': 'coTons', 'Population(2022)' : 'population'})

# %%
df1
# Out:
#            Country  Year       coTons  population      Area % of World
# 0      Afghanistan  1750          0.0  41128771.0  652230.0      0.40%  \
# 1      Afghanistan  1751          0.0  41128771.0  652230.0      0.40%
# 2      Afghanistan  1752          0.0  41128771.0  652230.0      0.40%
# 3      Afghanistan  1753          0.0  41128771.0  652230.0      0.40%
# 4      Afghanistan  1754          0.0  41128771.0  652230.0      0.40%
# ...            ...   ...          ...         ...       ...        ...
# 59615     Zimbabwe  2016  736467042.0  16320537.0  390757.0      0.30%
# 59616     Zimbabwe  2017  746048675.0  16320537.0  390757.0      0.30%
# 59617     Zimbabwe  2018  757903042.0  16320537.0  390757.0      0.30%
# 59618     Zimbabwe  2019  768852126.0  16320537.0  390757.0      0.30%
# 59619     Zimbabwe  2020  779383468.0  16320537.0  390757.0      0.30%
#
#       Density(km2)
# 0           63/km²
# 1           63/km²
# 2           63/km²
# 3           63/km²
# 4           63/km²
# ...            ...
# 59615       42/km²
# 59616       42/km²
# 59617       42/km²
# 59618       42/km²
# 59619       42/km²
#
# [59620 rows x 7 columns]

# %% [markdown]
# # Sorting the different columns to find correlations or anomalies

# %%
df1 = df1.sort_values('population', ascending = False)

# %%
df1
# Out:
#                  Country  Year        coTons    population       Area
# 10839              China  2020  2.360000e+11  1.425887e+09  9706961.0  \
# 10754              China  1935  8.434728e+08  1.425887e+09  9706961.0
# 10740              China  1921  3.175662e+08  1.425887e+09  9706961.0
# 10741              China  1922  3.441998e+08  1.425887e+09  9706961.0
# 10742              China  1923  3.763514e+08  1.425887e+09  9706961.0
# ...                  ...   ...           ...           ...        ...
# 58802  Wallis and Futuna  2016  4.030400e+05           NaN        NaN
# 58803  Wallis and Futuna  2017  4.286880e+05           NaN        NaN
# 58804  Wallis and Futuna  2018  4.543360e+05           NaN        NaN
# 58805  Wallis and Futuna  2019  4.807730e+05           NaN        NaN
# 58806  Wallis and Futuna  2020  5.072470e+05           NaN        NaN
#
#       % of World Density(km2)
# 10839      6.30%      147/km²
# 10754      6.30%      147/km²
# 10740      6.30%      147/km²
# 10741      6.30%      147/km²
# 10742      6.30%      147/km²
# ...          ...          ...
# 58802        NaN          NaN
# 58803        NaN          NaN
# 58804        NaN          NaN
# 58805        NaN          NaN
# 58806        NaN          NaN
#
# [59620 rows x 7 columns]

# %% [markdown]
# # as we can see, we have a lot of NaN value let's see in 2020 how many Country contain NaN information in this data set

# %% [markdown]
# # create filter for geting all data where year is 2020

# %%
dfSelect2020 = df1[df1['Year'] == 2020]

# %%
dfSelect2020
# Out:
#                          Country  Year        coTons    population       Area
# 10839                      China  2020  2.360000e+11  1.425887e+09  9706961.0  \
# 24389                      India  2020  5.441649e+10  1.417173e+09  3287590.0
# 57180              United States  2020  4.170000e+11  3.382899e+08  9372610.0
# 24660                  Indonesia  2020  1.439996e+10  2.755013e+08  1904569.0
# 40649                   Pakistan  2020  5.162289e+09  2.358249e+08   881912.0
# ...                          ...   ...           ...           ...        ...
# 45798  Saint Pierre and Miquelon  2020  3.676592e+06           NaN      242.0
# 48508  Sint Maarten (Dutch part)  2020  6.770353e+07           NaN        NaN
# 53657                      Timor  2020  6.543008e+06           NaN        NaN
# 55554   Turks and Caicos Islands  2020  3.930547e+06           NaN      948.0
# 58806          Wallis and Futuna  2020  5.072470e+05           NaN        NaN
#
#       % of World Density(km2)
# 10839      6.30%      147/km²
# 24389      2.00%      431/km²
# 57180      6.10%       36/km²
# 24660      1.20%      145/km²
# 40649      0.50%      267/km²
# ...          ...          ...
# 45798      0.00%          NaN
# 48508        NaN          NaN
# 53657        NaN          NaN
# 55554      0.00%          NaN
# 58806        NaN          NaN
#
# [220 rows x 7 columns]

# %% [markdown]
# # create filter for return all rows where one value have NaN on all columns

# %%
dfNull2020 = dfSelect2020[dfSelect2020.isna().any(axis=1)]

# %%
dfNull2020['Country']
# Out:
# 23576                       Hong Kong
# 41191                       Palestine
# 39836                 North Macedonia
# 27912                          Kosovo
# 43901                         Reunion
# 9755                       Cape Verde
# 7858                           Brunei
# 1625                         Anguilla
# 1896                       Antarctica
# 2980                            Aruba
# 6232                          Bermuda
# 11110                Christmas Island
# 11923                           Congo
# 12194                    Cook Islands
# 12736                   Cote d'Ivoire
# 13549                         Curacao
# 14091                         Czechia
# 14362    Democratic Republic of Congo
# 17885                  Faeroe Islands
# 19240                French Polynesia
# 22492                   Guinea-Bissau
# 31164                           Macao
# 35771                      Montserrat
# 37939                   New Caledonia
# 39294                            Niue
# 44985                    Saint Helena
# 45798       Saint Pierre and Miquelon
# 48508       Sint Maarten (Dutch part)
# 53657                           Timor
# 55554        Turks and Caicos Islands
# 58806               Wallis and Futuna
# Name: Country, dtype: object

# %% [markdown]
# # how many are them ?

# %%
len(dfNull2020.index)
# Out:
# 31

# %% [markdown]
# # pure curiosity, let's compare the most polluting to this group of countries

# %%
the31Union = dfNull2020['coTons'].sum()
theMostPoluating = dfSelect2020.nlargest(1, 'coTons')

# %%
x_value = [theMostPoluating['Country'].values[0], 'U34']
y_value = [theMostPoluating['coTons'].values[0], the31Union]

plt.bar( x_value, y_value)

plt.show()

# %% [markdown]
# # I'm curious to find out the number of countries required to match the CO2 emissions of the United States

# %%
dfSorted2020 = dfSelect2020.sort_values('coTons', ascending=True)
dfSorted2020
# Out:
#               Country  Year        coTons    population        Area
# 1896       Antarctica  2020  1.538880e+05           NaN         NaN  \
# 43359     Puerto Rico  2020  2.088480e+05  3.252407e+06      8870.0
# 55825          Tuvalu  2020  2.789250e+05  1.131200e+04        26.0
# 39294            Niue  2020  2.901480e+05           NaN       260.0
# 44985    Saint Helena  2020  3.792950e+05           NaN       394.0
# ...               ...   ...           ...           ...         ...
# 56909  United Kingdom  2020  7.816115e+10  6.750894e+07    242900.0
# 20324         Germany  2020  9.263562e+10  8.336984e+07    357114.0
# 44443          Russia  2020  1.150000e+11  1.447133e+08  17098242.0
# 10839           China  2020  2.360000e+11  1.425887e+09   9706961.0
# 57180   United States  2020  4.170000e+11  3.382899e+08   9372610.0
#
#       % of World Density(km2)
# 1896         NaN          NaN
# 43359      0.00%      367/km²
# 55825      0.00%      435/km²
# 39294      0.00%          NaN
# 44985      0.00%          NaN
# ...          ...          ...
# 56909      0.20%      278/km²
# 20324      0.20%      233/km²
# 44443     11.00%        8/km²
# 10839      6.30%      147/km²
# 57180      6.10%       36/km²
#
# [220 rows x 7 columns]

# %%
i = 0
countriesSumsCo2 = 0
dfCountriesSums = pd.DataFrame(columns=df1.columns)

# %%
while theMostPoluating['coTons'].values[0] > countriesSumsCo2 :
    
    countriesSumsCo2 += dfSorted2020['coTons'].values[i] 

    row = pd.DataFrame([dfSorted2020.iloc[i]])
    dfCountriesSums = pd.concat([dfCountriesSums, row])

    
    i += 1
print(str(i) + " " + str(countriesSumsCo2))
# Out:
# 207 418617496416.0

# %%
dfCountriesSums
# Out:
#             Country  Year        coTons   population       Area % of World
# 1896     Antarctica  2020  1.538880e+05          NaN        NaN        NaN  \
# 43359   Puerto Rico  2020  2.088480e+05    3252407.0     8870.0      0.00%
# 55825        Tuvalu  2020  2.789250e+05      11312.0       26.0      0.00%
# 39294          Niue  2020  2.901480e+05          NaN      260.0      0.00%
# 44985  Saint Helena  2020  3.792950e+05          NaN      394.0      0.00%
# ...             ...   ...           ...          ...        ...        ...
# 7587         Brazil  2020  1.623851e+10  215313498.0  8515767.0      5.60%
# 50134   South Korea  2020  1.833571e+10   51815810.0   100210.0      0.10%
# 3251      Australia  2020  1.863575e+10   26177413.0  7692024.0      5.20%
# 24931          Iran  2020  1.891444e+10   88550570.0  1648195.0      1.10%
# 34416        Mexico  2020  2.007501e+10  127504125.0  1964375.0      1.30%
#
#       Density(km2)
# 1896           NaN
# 43359      367/km²
# 55825      435/km²
# 39294          NaN
# 44985          NaN
# ...            ...
# 7587        25/km²
# 50134      517/km²
# 3251         3/km²
# 24931       54/km²
# 34416       65/km²
#
# [207 rows x 7 columns]

# %% [markdown]
# # After observing this, i understand that CO2 emissions are cumulative from 1700 rather than being based annualy starting from 1700.

# %% [markdown]
# # and when we see the united state at 417 billion tons co2Tons that confirm the data 'coTons' is cumulative and not based annualy

# %% [markdown]
# # let's get 10 country who generated the most of c02 in 2020

# %%
df2020Big = dfSelect2020.nlargest(10, 'coTons')

# %%
df2020Big
# Out:
#               Country  Year        coTons    population        Area
# 57180   United States  2020  4.170000e+11  3.382899e+08   9372610.0  \
# 10839           China  2020  2.360000e+11  1.425887e+09   9706961.0
# 44443          Russia  2020  1.150000e+11  1.447133e+08  17098242.0
# 20324         Germany  2020  9.263562e+10  8.336984e+07    357114.0
# 56909  United Kingdom  2020  7.816115e+10  6.750894e+07    242900.0
# 26557           Japan  2020  6.562517e+10  1.239517e+08    377930.0
# 24389           India  2020  5.441649e+10  1.417173e+09   3287590.0
# 18698          France  2020  3.872868e+10  6.462663e+07    551695.0
# 9484           Canada  2020  3.357674e+10  3.845433e+07   9984670.0
# 56367         Ukraine  2020  3.055916e+10  3.970174e+07    603500.0
#
#       % of World Density(km2)
# 57180      6.10%       36/km²
# 10839      6.30%      147/km²
# 44443     11.00%        8/km²
# 20324      0.20%      233/km²
# 56909      0.20%      278/km²
# 26557      0.20%      328/km²
# 24389      2.00%      431/km²
# 18698      0.40%      117/km²
# 9484       6.10%        4/km²
# 56367      0.40%       66/km²

# %% [markdown]
# # Getting data from all year for the 10 selected

# %%
allYearCO2Big = df1[df1['Country'].isin(df2020Big['Country'])]

# %%
allYearCO2Big
# Out:
#       Country  Year        coTons    population       Area % of World
# 10839   China  2020  2.360000e+11  1.425887e+09  9706961.0      6.30%  \
# 10754   China  1935  8.434728e+08  1.425887e+09  9706961.0      6.30%
# 10740   China  1921  3.175662e+08  1.425887e+09  9706961.0      6.30%
# 10741   China  1922  3.441998e+08  1.425887e+09  9706961.0      6.30%
# 10742   China  1923  3.763514e+08  1.425887e+09  9706961.0      6.30%
# ...       ...   ...           ...           ...        ...        ...
# 9309   Canada  1845  2.235040e+05  3.845433e+07  9984670.0      6.10%
# 9310   Canada  1846  2.491520e+05  3.845433e+07  9984670.0      6.10%
# 9311   Canada  1847  2.821280e+05  3.845433e+07  9984670.0      6.10%
# 9483   Canada  2019  3.304092e+10  3.845433e+07  9984670.0      6.10%
# 9349   Canada  1885  7.003736e+07  3.845433e+07  9984670.0      6.10%
#
#       Density(km2)
# 10839      147/km²
# 10754      147/km²
# 10740      147/km²
# 10741      147/km²
# 10742      147/km²
# ...            ...
# 9309         4/km²
# 9310         4/km²
# 9311         4/km²
# 9483         4/km²
# 9349         4/km²
#
# [2710 rows x 7 columns]

# %% [markdown]
# # creating pivot_table for setting year as index and country as column for Emission though year on graph

# %%
pivot_table = allYearCO2Big.pivot_table(values='coTons', index='Year', columns='Country')

# %%
pivot_table.plot()
plt.ylabel('CO2 TONS')
plt.title('CO2 Emissions over time')
plt.show()

# %% [markdown]
# # Let's see now how it was on the 19th century

# %%
dfCentury19 = allYearCO2Big[(allYearCO2Big['Year'] >= 1800) & (allYearCO2Big['Year'] <= 1900)]

# %%
pivot_table = dfCentury19.pivot_table(values='coTons', index='Year', columns='Country')

# %%
pivot_table.plot()
plt.ylabel('CO2 TONS')
plt.title('CO2 Emissions over time')
plt.show()

# %% [markdown]
# # Let's see now how it was on the 20th century

# %%
dfCentury20 = allYearCO2Big[(allYearCO2Big['Year'] >= 1900) & (allYearCO2Big['Year'] <= 2000)]

# %%
pivot_table = dfCentury20.pivot_table(values='coTons', index='Year', columns='Country')

# %%
pivot_table.plot()
plt.ylabel('CO2 TONS')
plt.title('CO2 Emissions over time')
plt.show()

# %% [markdown]
# # Let's see now how it was on the 20th century

# %%
dfCentury21 = allYearCO2Big[(allYearCO2Big['Year'] >= 2000) & (allYearCO2Big['Year'] <= 2020)]

# %%
pivot_table = dfCentury21.pivot_table(values='coTons', index='Year', columns='Country')

# %%
pivot_table
# Out:
# Country        Canada         China        France       Germany         India
# Year
# 2000     2.218015e+10  7.488403e+10  3.142863e+10  7.621667e+10  1.893972e+10  \
# 2001     2.273920e+10  7.839897e+10  3.183916e+10  7.713332e+10  1.993228e+10
# 2002     2.330387e+10  8.227156e+10  3.224517e+10  7.803329e+10  2.095531e+10
# 2003     2.388621e+10  8.681658e+10  3.265712e+10  7.893444e+10  2.201493e+10
# 2004     2.446697e+10  9.204033e+10  3.307027e+10  7.982153e+10  2.314040e+10
# 2005     2.504282e+10  9.791689e+10  3.348578e+10  8.068823e+10  2.432635e+10
# 2006     2.561423e+10  1.040000e+11  3.389154e+10  8.156655e+10  2.558610e+10
# 2007     2.620889e+10  1.110000e+11  3.428697e+10  8.241817e+10  2.694425e+10
# 2008     2.678826e+10  1.190000e+11  3.467496e+10  8.327310e+10  2.840706e+10
# 2009     2.733487e+10  1.270000e+11  3.504359e+10  8.406339e+10  3.001988e+10
# 2010     2.789368e+10  1.350000e+11  3.542017e+10  8.489634e+10  3.169777e+10
# 2011     2.846355e+10  1.450000e+11  3.577391e+10  8.570556e+10  3.347790e+10
# 2012     2.903281e+10  1.550000e+11  3.612984e+10  8.651954e+10  3.544148e+10
# 2013     2.960651e+10  1.650000e+11  3.648737e+10  8.735100e+10  3.747842e+10
# 2014     3.017707e+10  1.750000e+11  3.681326e+10  8.814359e+10  3.966428e+10
# 2015     3.075013e+10  1.840000e+11  3.714317e+10  8.893920e+10  4.193284e+10
# 2016     3.130970e+10  1.940000e+11  3.747675e+10  8.973988e+10  4.431507e+10
# 2017     3.187906e+10  2.040000e+11  3.781374e+10  9.052577e+10  4.674892e+10
# 2018     3.245853e+10  2.140000e+11  3.813612e+10  9.127988e+10  4.934873e+10
# 2019     3.304092e+10  2.250000e+11  3.845205e+10  9.199130e+10  5.197470e+10
# 2020     3.357674e+10  2.360000e+11  3.872868e+10  9.263562e+10  5.441649e+10
#
# Country         Japan        Russia       Ukraine  United Kingdom
# Year
# 2000     4.100939e+10  8.332305e+10  2.494736e+10    6.847098e+10  \
# 2001     4.225916e+10  8.483076e+10  2.525092e+10    6.904729e+10
# 2002     4.353828e+10  8.632645e+10  2.554660e+10    6.960736e+10
# 2003     4.482575e+10  8.785206e+10  2.585361e+10    7.017883e+10
# 2004     4.610861e+10  8.938275e+10  2.616398e+10    7.075173e+10
# 2005     4.739898e+10  9.093035e+10  2.647710e+10    7.132169e+10
# 2006     4.866634e+10  9.253690e+10  2.680977e+10    7.188926e+10
# 2007     4.996948e+10  9.414145e+10  2.714613e+10    7.244850e+10
# 2008     5.120179e+10  9.577837e+10  2.747166e+10    7.299300e+10
# 2009     5.236500e+10  9.730733e+10  2.774896e+10    7.348689e+10
# 2010     5.357982e+10  9.892044e+10  2.804303e+10    7.399853e+10
# 2011     5.484469e+10  1.010000e+11  2.835099e+10    7.446798e+10
# 2012     5.615070e+10  1.020000e+11  2.865496e+10    7.495550e+10
# 2013     5.746604e+10  1.040000e+11  2.895221e+10    7.543288e+10
# 2014     5.872977e+10  1.060000e+11  2.920972e+10    7.587142e+10
# 2015     5.995316e+10  1.070000e+11  2.943354e+10    7.629376e+10
# 2016     6.115688e+10  1.090000e+11  2.966755e+10    7.669310e+10
# 2017     6.234500e+10  1.100000e+11  2.989064e+10    7.708067e+10
# 2018     6.348846e+10  1.120000e+11  3.012267e+10    7.746256e+10
# 2019     6.459439e+10  1.140000e+11  3.034525e+10    7.783157e+10
# 2020     6.562517e+10  1.150000e+11  3.055916e+10    7.816115e+10
#
# Country  United States
# Year
# 2000      3.040000e+11
# 2001      3.100000e+11
# 2002      3.160000e+11
# 2003      3.220000e+11
# 2004      3.280000e+11
# 2005      3.340000e+11
# 2006      3.400000e+11
# 2007      3.470000e+11
# 2008      3.530000e+11
# 2009      3.580000e+11
# 2010      3.640000e+11
# 2011      3.690000e+11
# 2012      3.750000e+11
# 2013      3.800000e+11
# 2014      3.860000e+11
# 2015      3.910000e+11
# 2016      3.960000e+11
# 2017      4.010000e+11
# 2018      4.070000e+11
# 2019      4.120000e+11
# 2020      4.170000e+11

# %%
pivot_table.plot()
plt.ylabel('CO2 TONS')
plt.title('CO2 Emissions over time')
plt.show()

# %% [markdown]
# # as we can see i have a problem on my X axis
