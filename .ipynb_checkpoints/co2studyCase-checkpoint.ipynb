# %% [markdown]
# # Study of Co2 from 1700 to 2020 by country

# %%
#######################################################################

# %% [markdown]
# # Imports librairies

# %%
import pandas as pd

# %% [markdown]
# # import data from csv

# %%
data = pd.read_csv("co2_emission_by_countries.csv", encoding="latin")

# %% [markdown]
# # reading data as dataframe

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#            Country Code Calling Code  Year  CO2 emission (Tons)
# 0      Afghanistan   AF           93  1750                  0.0  \
# 1      Afghanistan   AF           93  1751                  0.0
# 2      Afghanistan   AF           93  1752                  0.0
# 3      Afghanistan   AF           93  1753                  0.0
# 4      Afghanistan   AF           93  1754                  0.0
# ...            ...  ...          ...   ...                  ...
# 59615     Zimbabwe   ZW          263  2016          736467042.0
# 59616     Zimbabwe   ZW          263  2017          746048675.0
# 59617     Zimbabwe   ZW          263  2018          757903042.0
# 59618     Zimbabwe   ZW          263  2019          768852126.0
# 59619     Zimbabwe   ZW          263  2020          779383468.0
#
#        Population(2022)      Area % of World Density(km2)
# 0            41128771.0  652230.0      0.40%       63/km²
# 1            41128771.0  652230.0      0.40%       63/km²
# 2            41128771.0  652230.0      0.40%       63/km²
# 3            41128771.0  652230.0      0.40%       63/km²
# 4            41128771.0  652230.0      0.40%       63/km²
# ...                 ...       ...        ...          ...
# 59615        16320537.0  390757.0      0.30%       42/km²
# 59616        16320537.0  390757.0      0.30%       42/km²
# 59617        16320537.0  390757.0      0.30%       42/km²
# 59618        16320537.0  390757.0      0.30%       42/km²
# 59619        16320537.0  390757.0      0.30%       42/km²
#
# [59620 rows x 9 columns]

# %% [markdown]
# # Remove usless columns as "Calling code" and "Code"

# %%
df1 = df.drop(columns=['Calling Code','Code'])

# %%
df1
# Out:
#            Country  Year  CO2 emission (Tons)  Population(2022)      Area
# 0      Afghanistan  1750                  0.0        41128771.0  652230.0  \
# 1      Afghanistan  1751                  0.0        41128771.0  652230.0
# 2      Afghanistan  1752                  0.0        41128771.0  652230.0
# 3      Afghanistan  1753                  0.0        41128771.0  652230.0
# 4      Afghanistan  1754                  0.0        41128771.0  652230.0
# ...            ...   ...                  ...               ...       ...
# 59615     Zimbabwe  2016          736467042.0        16320537.0  390757.0
# 59616     Zimbabwe  2017          746048675.0        16320537.0  390757.0
# 59617     Zimbabwe  2018          757903042.0        16320537.0  390757.0
# 59618     Zimbabwe  2019          768852126.0        16320537.0  390757.0
# 59619     Zimbabwe  2020          779383468.0        16320537.0  390757.0
#
#       % of World Density(km2)
# 0          0.40%       63/km²
# 1          0.40%       63/km²
# 2          0.40%       63/km²
# 3          0.40%       63/km²
# 4          0.40%       63/km²
# ...          ...          ...
# 59615      0.30%       42/km²
# 59616      0.30%       42/km²
# 59617      0.30%       42/km²
# 59618      0.30%       42/km²
# 59619      0.30%       42/km²
#
# [59620 rows x 7 columns]

# %% [markdown]
# # Rename columns of select easier

# %%
df1 = df1.rename(columns={'CO2 emission (Tons)': 'coTons', 'Population(2022)' : 'population'})

# %%
df1
# Out:
#            Country  Year       coTons  population      Area % of World
# 0      Afghanistan  1750          0.0  41128771.0  652230.0      0.40%  \
# 1      Afghanistan  1751          0.0  41128771.0  652230.0      0.40%
# 2      Afghanistan  1752          0.0  41128771.0  652230.0      0.40%
# 3      Afghanistan  1753          0.0  41128771.0  652230.0      0.40%
# 4      Afghanistan  1754          0.0  41128771.0  652230.0      0.40%
# ...            ...   ...          ...         ...       ...        ...
# 59615     Zimbabwe  2016  736467042.0  16320537.0  390757.0      0.30%
# 59616     Zimbabwe  2017  746048675.0  16320537.0  390757.0      0.30%
# 59617     Zimbabwe  2018  757903042.0  16320537.0  390757.0      0.30%
# 59618     Zimbabwe  2019  768852126.0  16320537.0  390757.0      0.30%
# 59619     Zimbabwe  2020  779383468.0  16320537.0  390757.0      0.30%
#
#       Density(km2)
# 0           63/km²
# 1           63/km²
# 2           63/km²
# 3           63/km²
# 4           63/km²
# ...            ...
# 59615       42/km²
# 59616       42/km²
# 59617       42/km²
# 59618       42/km²
# 59619       42/km²
#
# [59620 rows x 7 columns]

# %% [markdown]
# # Sorting the different columns to find correlations or anomalies

# %%
df1 = df1.sort_values('population', ascending = False)

# %%
df1
# Out:
#                  Country  Year        coTons    population       Area
# 10839              China  2020  2.360000e+11  1.425887e+09  9706961.0  \
# 10754              China  1935  8.434728e+08  1.425887e+09  9706961.0
# 10740              China  1921  3.175662e+08  1.425887e+09  9706961.0
# 10741              China  1922  3.441998e+08  1.425887e+09  9706961.0
# 10742              China  1923  3.763514e+08  1.425887e+09  9706961.0
# ...                  ...   ...           ...           ...        ...
# 58802  Wallis and Futuna  2016  4.030400e+05           NaN        NaN
# 58803  Wallis and Futuna  2017  4.286880e+05           NaN        NaN
# 58804  Wallis and Futuna  2018  4.543360e+05           NaN        NaN
# 58805  Wallis and Futuna  2019  4.807730e+05           NaN        NaN
# 58806  Wallis and Futuna  2020  5.072470e+05           NaN        NaN
#
#       % of World Density(km2)
# 10839      6.30%      147/km²
# 10754      6.30%      147/km²
# 10740      6.30%      147/km²
# 10741      6.30%      147/km²
# 10742      6.30%      147/km²
# ...          ...          ...
# 58802        NaN          NaN
# 58803        NaN          NaN
# 58804        NaN          NaN
# 58805        NaN          NaN
# 58806        NaN          NaN
#
# [59620 rows x 7 columns]

# %% [markdown]
# # as we can see, we have a lot of NaN value let's see in 2020 how many Country contain NaN information in this data set
